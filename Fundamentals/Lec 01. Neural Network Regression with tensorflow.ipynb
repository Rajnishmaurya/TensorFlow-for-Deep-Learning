# %% [markdown]
# architecture of a regresison neural network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  A hyperparameter in machine learning is something a data analyst or developer can set themselves, where as a parameter usually describes something a model learns on its own (a value not explicitly set by an analyst).

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import datetime
print(f"Notebook last run (end-to-run):{datetime.datetime.now()}")
# Out:
# Notebook last run (end-to-run):2025-07-13 18:12:14.911173

# %% [markdown]
# Creating a data to view and fit

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

plt.scatter(X,y)

# %% [markdown]
# Regression input shapes and output shapes

# %% [markdown]
# The input shape is the shape of your data that goes into the model.
#
# The output shape is the shape of your data you want to come out of your model.

# %%
# exmaple input and output shapes of a regression model

house_info=tf.constant(["bedroom","bathroom","garage"])
house_price=tf.constant([939700])

house_info,house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
house_info.shape,house_price.shape
# Out:
# (TensorShape([3]), TensorShape([1]))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create features (using tensors)
X = tf.constant([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels (using tensors)
y = tf.constant([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y);

# %%
X.shape,y.shape
# Out:
# (TensorShape([8]), TensorShape([8]))

# %% [markdown]
# Steps in modelling with TensorFlow
